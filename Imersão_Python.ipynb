# %% [markdown]
# <a href="https://colab.research.google.com/github/AngeloDomingues/An-lise-de-Dados/blob/main/Imers%C3%A3o_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importação Python

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/Imersão_Python.xlsx", sheet_name="Principal")
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Variação %  \
# 0  USIM5 2024-01-26         9.50          5.20        0.05
# 1  CMIN3 2024-01-26         6.82          2.40        0.02
# 2  PETR3 2024-01-26        41.96          2.19        0.02
# 3  SUZB3 2024-01-26        52.91          2.04        0.02
# 4  CPFE3 2024-01-26        37.10          2.03        0.02
# 5  PRIO3 2024-01-26        45.69          1.98        0.02
# 6  PETR4 2024-01-26        39.96          1.73        0.02
# 7  VALE3 2024-01-26        69.50          1.66        0.02
# 8  MULT3 2024-01-26        28.19          1.58        0.02
# 9  ITUB4 2024-01-26        32.81          1.48        0.01
#
#    Variação Inical (R$)  Quantidades de Ações    Variação $ Resultado  \
# 0                  9.03             515117391  241889725.43     Subiu
# 1                  6.66            1110559345  177515970.30     Subiu
# 2                 41.06            2379877655 2140059393.53     Subiu
# 3                 51.85             683452836  722946282.71     Subiu
# 4                 36.36             187732538  138573955.06     Subiu
# 5                 44.80             800010734  709687498.18     Subiu
# 6                 39.28            4566445852 3103136291.22     Subiu
# 7                 68.37            4196924316 4762926995.25     Subiu
# 8                 27.75             268505432  117732680.08     Subiu
# 9                 32.33            4801593832 2297591984.33     Subiu
#
#   Nome da Empresa    Segmento  Idade            Cat_Idade  Var. Sem. (%)  \
# 0        Usiminas  Siderurgia     63  Entre 50 e 100 anos          11.76
# 1   CSN Mineração  Siderurgia      9     Menos de 50 anos           2.40
# 2       Petrobras    Petróleo     72  Entre 50 e 100 anos           7.73
# 3          Suzano       Papel    101     Mais de 100 anos           2.14
# 4    CPFL Energia     Energia    112     Mais de 100 anos           2.49
# 5        PetroRio    Petróleo     14     Menos de 50 anos           2.42
# 6       Petrobras    Petróleo     72  Entre 50 e 100 anos           6.47
# 7            Vale   Mineração     83  Entre 50 e 100 anos           2.06
# 8       Multiplan    Shopping     51  Entre 50 e 100 anos           2.03
# 9   Itaú Unibanco      Bancos    100  Entre 50 e 100 anos          -0.39
#
#    Var. Mês (%)  Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume
# 0          2.26          2.26         15.97      9.18      9.56  319,16 M
# 1        -12.11        -12.11         50.56      6.66      6.86   32,65 M
# 2          7.64          7.64         77.55     40.81     42.34  436,69 M
# 3         -4.89         -4.89         18.85     51.89     53.17  162,55 M
# 4         -3.66         -3.66         20.70     36.37     37.32   73,42 M
# 5         -0.78         -0.78          8.08     44.25     45.69  319,92 M
# 6          7.30          7.30         95.01     38.91     40.09    1,64 B
# 7         -9.97         -9.97        -23.49     67.50     69.81    1,89 B
# 8         -0.81         -0.81         24.02     27.71     28.36  104,16 M
# 9         -3.36         -3.36         34.25     32.35     32.91   473,2 M

# %%
df_Análises = pd.read_excel("/content/Imersão_Python.xlsx", sheet_name="Análises")
df_Análises.head(10)
# Out:
#                   Maior  4762926995.25                    Vale
# 0                 Menor -1807432634.46                Localiza
# 1                 Média   165190210.48                     NaN
# 2   Média de quem subiu   448164250.23                     NaN
# 3  Média de quem desceu  -181109141.75                     NaN
# 4                   NaN            NaN                     NaN
# 5                   NaN            NaN                     NaN
# 6                   NaN            NaN                     NaN
# 7              Segmento       Variação  Variação de quem subiu
# 8            Siderurgia   667451901.23            667451901.23
# 9              Petróleo  6093288832.26           6093288832.26

# %%
df_Chat_GPT = pd.read_excel("/content/Imersão_Python.xlsx", sheet_name="Chat_GPT")
df_Chat_GPT.head(10)
# Out:
#   Nome da Empresa    Segmento  Idade (anos)
# 0        Usiminas  Siderurgia            63
# 1   CSN Mineração  Siderurgia             9
# 2       Petrobras    Petróleo            72
# 3          Suzano       Papel           101
# 4    CPFL Energia     Energia           112
# 5        PetroRio    Petróleo            14
# 6       Petrobras    Petróleo            72
# 7            Vale   Mineração            83
# 8       Multiplan    Shopping            51
# 9   Itaú Unibanco      Bancos           100

# %%
df_Total_de_Acoes = pd.read_excel("/content/Imersão_Python.xlsx", sheet_name="Total_de_acoes")
df_Total_de_Acoes.head(10)
# Out:
#   Código  Qtde. Teórica
# 0  RRRP3   235665566.00
# 1  ALOS3   532616595.00
# 2  ALPA4   176733968.00
# 3  ABEV3  4394245879.00
# 4  ARZZ3    62305891.00
# 5  ASAI3  1349217892.00
# 6  AZUL4   327593725.00
# 7  B3SA3  5602790110.00
# 8  BBSE3   671750768.00
# 9  BBDC3  1500728902.00

# %%
df_Ticker = pd.read_excel("/content/Imersão_Python.xlsx", sheet_name="Ticker")
df_Ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'Valor_Final', 'Var. Dia (%)':'Var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal["Var_pct"] = df_principal["Var_dia_pct"] / 100
df_principal["Valor_Inicial"] = df_principal["Valor_Final"] / (df_principal["Var_pct"] + 1)
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_Total_de_Acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 7 columns]

# %%
df_principal['Variacao_rs'] = (df_principal['Valor_Final'] - df_principal['Valor_Inicial'])*df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'Qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# 2    2379877655  2140059393.53
# 3     683452836   722946282.71
# 4     187732538   138573955.06
# ..          ...            ...
# 76    533990587  -143635530.57
# 77     94843047   -20810240.84
# 78    853202347 -1807432634.46
# 79    525582771   -73557408.06
# 80    198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Manteve'))
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado
# 0     515117391   241889725.43     Subiu
# 1    1110559345   177515970.30     Subiu
# 2    2379877655  2140059393.53     Subiu
# 3     683452836   722946282.71     Subiu
# 4     187732538   138573955.06     Subiu
# ..          ...            ...       ...
# 76    533990587  -143635530.57    Desceu
# 77     94843047   -20810240.84    Desceu
# 78    853202347 -1807432634.46    Desceu
# 79    525582771   -73557408.06    Desceu
# 80    198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_Ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_Chat_GPT, left_on='Nome', right_on='Nome da Empresa', how='left')
df_principal = df_principal.drop(columns=['Nome da Empresa'])
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 80  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 81  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 82  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 83  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 84  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome    Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas  Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração  Siderurgia
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo
# 3    2379877655  2140059393.53     Subiu         Petrobras    Petróleo
# 4     683452836   722946282.71     Subiu            Suzano       Papel
# ..          ...            ...       ...               ...         ...
# 80    533990587  -143635530.57    Desceu  Carrefour Brasil      Varejo
# 81     94843047   -20810240.84    Desceu       Casas Bahia     Turismo
# 82    853202347 -1807432634.46    Desceu          Localiza     Locação
# 83    525582771   -73557408.06    Desceu               CVC     Turismo
# 84    198184909  -102993202.62    Desceu               GOL     Aviação
#
#     Idade (anos)
# 0             63
# 1              9
# 2             72
# 3             72
# 4            101
# ..           ...
# 80            49
# 81            73
# 82            52
# 83            52
# 84            25
#
# [85 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade (anos)':'Idade'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 80  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 81  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 82  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 83  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 84  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome    Segmento  Idade
# 0     515117391   241889725.43     Subiu          Usiminas  Siderurgia     63
# 1    1110559345   177515970.30     Subiu     CSN Mineração  Siderurgia      9
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo     72
# 3    2379877655  2140059393.53     Subiu         Petrobras    Petróleo     72
# 4     683452836   722946282.71     Subiu            Suzano       Papel    101
# ..          ...            ...       ...               ...         ...    ...
# 80    533990587  -143635530.57    Desceu  Carrefour Brasil      Varejo     49
# 81     94843047   -20810240.84    Desceu       Casas Bahia     Turismo     73
# 82    853202347 -1807432634.46    Desceu          Localiza     Locação     52
# 83    525582771   -73557408.06    Desceu               CVC     Turismo     52
# 84    198184909  -102993202.62    Desceu               GOL     Aviação     25
#
# [85 rows x 12 columns]

# %%
df_principal['Cat_Idade'] = df_principal['Idade'].apply(lambda x: 'Mais de 100' if x > 100 else ('Menos de 50' if x < 50 else 'Entre 50 e 100'))
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 80  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 81  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 82  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 83  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 84  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome    Segmento  Idade  \
# 0     515117391   241889725.43     Subiu          Usiminas  Siderurgia     63
# 1    1110559345   177515970.30     Subiu     CSN Mineração  Siderurgia      9
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo     72
# 3    2379877655  2140059393.53     Subiu         Petrobras    Petróleo     72
# 4     683452836   722946282.71     Subiu            Suzano       Papel    101
# ..          ...            ...       ...               ...         ...    ...
# 80    533990587  -143635530.57    Desceu  Carrefour Brasil      Varejo     49
# 81     94843047   -20810240.84    Desceu       Casas Bahia     Turismo     73
# 82    853202347 -1807432634.46    Desceu          Localiza     Locação     52
# 83    525582771   -73557408.06    Desceu               CVC     Turismo     52
# 84    198184909  -102993202.62    Desceu               GOL     Aviação     25
#
#          Cat_Idade
# 0   Entre 50 e 100
# 1      Menos de 50
# 2   Entre 50 e 100
# 3   Entre 50 e 100
# 4      Mais de 100
# ..             ...
# 80     Menos de 50
# 81  Entre 50 e 100
# 82  Entre 50 e 100
# 83  Entre 50 e 100
# 84     Menos de 50
#
# [85 rows x 13 columns]

# %%
# Maior
maior = df_principal["Variacao_rs"].max()

# Menor
menor = df_principal["Variacao_rs"].min()

# Média geral
media = df_principal["Variacao_rs"].mean()

# Média de quem subiu
media_subiu = df_principal[df_principal["Resultado"] == "Subiu"]["Variacao_rs"].mean()

# Média de quem desceu
media_desceu = df_principal[df_principal["Resultado"] == "Desceu"]["Variacao_rs"].mean()

print(f"maior\tR$ {maior:,.2f}")
print(f"menor\tR$ {menor:,.2f}")
print(f"media\tR$ {media:,.2f}")
print(f"média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# maior	R$ 4,762,926,995.25
# menor	R$ -1,807,432,634.46
# media	R$ 229,644,360.94
# média de quem subiu	R$ 538,720,638.36
# média de quem desceu	R$ -181,109,141.75

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 80  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 81  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 82  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 83  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 84  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome    Segmento  Idade  \
# 0     515117391   241889725.43     Subiu          Usiminas  Siderurgia     63
# 1    1110559345   177515970.30     Subiu     CSN Mineração  Siderurgia      9
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo     72
# 3    2379877655  2140059393.53     Subiu         Petrobras    Petróleo     72
# 4     683452836   722946282.71     Subiu            Suzano       Papel    101
# ..          ...            ...       ...               ...         ...    ...
# 80    533990587  -143635530.57    Desceu  Carrefour Brasil      Varejo     49
# 81     94843047   -20810240.84    Desceu       Casas Bahia     Turismo     73
# 82    853202347 -1807432634.46    Desceu          Localiza     Locação     52
# 83    525582771   -73557408.06    Desceu               CVC     Turismo     52
# 84    198184909  -102993202.62    Desceu               GOL     Aviação     25
#
#          Cat_Idade
# 0   Entre 50 e 100
# 1      Menos de 50
# 2   Entre 50 e 100
# 3   Entre 50 e 100
# 4      Mais de 100
# ..             ...
# 80     Menos de 50
# 81  Entre 50 e 100
# 82  Entre 50 e 100
# 83  Entre 50 e 100
# 84     Menos de 50
#
# [85 rows x 13 columns]

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#             Segmento    Variacao_rs
# 0          Alimentos   407833683.09
# 1            Aviação    65452205.55
# 2             Bancos  4636679965.25
# 3       Combustíveis   388705223.96
# 4         Construção    37525872.38
# 5           Educação    72295838.99
# 6            Energia   821116399.61
# 7            Holding   416092244.42
# 8          Logística   233902674.79
# 9            Madeira    18068446.61
# 10             Meios    43657683.38
# 11         Mineração  4762926995.25
# 12              Moda    41021792.09
# 13             Papel   722946282.71
# 14      Petroquímica    69054317.64
# 15          Petróleo 11336484517.00
# 16             Saúde   453917907.01
# 17          Shopping   117732680.08
# 18        Siderurgia   667451901.23
# 19        Tecnologia    15598886.65
# 20   Telecomunicação   188965307.06
# 21  Telecomunicações   103972807.37
# 22            Varejo   237187009.24

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
display(df_principal_subiu)
# Out:
#     Ativo       Data  Valor_Final  Var_dia_pct  Var_pct  Valor_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 5   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 6   PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 7   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 8   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 9   VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 10  MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 11  ITUB4 2024-01-26        32.81         1.48     0.01          32.33
# 12  RDOR3 2024-01-26        27.56         1.43     0.01          27.17
# 13  BRKM5 2024-01-26        18.55         1.42     0.01          18.29
# 14  AZUL4 2024-01-26        14.27         1.42     0.01          14.07
# 15  RRRP3 2024-01-26        28.75         1.41     0.01          28.35
# 16  EQTL3 2024-01-26        35.32         1.34     0.01          34.85
# 17  CSNA3 2024-01-26        18.16         1.33     0.01          17.92
# 18  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
# 19  UGPA3 2024-01-26        28.31         1.28     0.01          27.95
# 20  MRVE3 2024-01-26         8.08         1.25     0.01           7.98
# 21  ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 22  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 23  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 24  BEEF3 2024-01-26         7.19         0.98     0.01           7.12
# 25  PCAR3 2024-01-26         4.14         0.97     0.01           4.10
# 26  BRFS3 2024-01-26        14.61         0.96     0.01          14.47
# 27  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 28  RAIL3 2024-01-26        22.64         0.84     0.01          22.45
# 29  CIEL3 2024-01-26         4.90         0.82     0.01           4.86
# 30  DXCO3 2024-01-26         7.81         0.77     0.01           7.75
# 31  TIMS3 2024-01-26        17.52         0.74     0.01          17.39
# 32  BRAP4 2024-01-26        23.22         0.73     0.01          23.05
# 33  LWSA3 2024-01-26         5.55         0.72     0.01           5.51
# 34  RECV3 2024-01-26        23.83         0.71     0.01          23.66
# 35  ITSA4 2024-01-26        10.01         0.70     0.01           9.94
# 36  BBAS3 2024-01-26        56.97         0.68     0.01          56.59
# 37  RADL3 2024-01-26        26.16         0.61     0.01          26.00
# 38  GOAU4 2024-01-26        10.08         0.59     0.01          10.02
# 39  CSAN3 2024-01-26        18.57         0.59     0.01          18.46
# 40  JBSS3 2024-01-26        24.34         0.57     0.01          24.20
# 41  MGLU3 2024-01-26         2.08         0.48     0.00           2.07
# 42  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 43  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 44  GGBR4 2024-01-26        21.84         0.27     0.00          21.78
# 45  RAIZ4 2024-01-26         3.74         0.26     0.00           3.73
# 46  CPLE6 2024-01-26        10.07         0.19     0.00          10.05
# 47  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
#
#     Qtd_teorica   Variacao_rs Resultado                  Nome  \
# 0     515117391  241889725.43     Subiu              Usiminas
# 1    1110559345  177515970.30     Subiu         CSN Mineração
# 2    2379877655 2140059393.53     Subiu             Petrobras
# 3    2379877655 2140059393.53     Subiu             Petrobras
# 4     683452836  722946282.71     Subiu                Suzano
# 5     187732538  138573955.06     Subiu          CPFL Energia
# 6     800010734  709687498.18     Subiu              PetroRio
# 7    4566445852 3103136291.22     Subiu             Petrobras
# 8    4566445852 3103136291.22     Subiu             Petrobras
# 9    4196924316 4762926995.25     Subiu                  Vale
# 10    268505432  117732680.08     Subiu             Multiplan
# 11   4801593832 2297591984.33     Subiu         Itaú Unibanco
# 12   1168230366  453917907.01     Subiu             Rede D'Or
# 13    265877867   69054317.64     Subiu               Braskem
# 14    327593725   65452205.55     Subiu                  Azul
# 15    235665566   94204643.35     Subiu          3R Petroleum
# 16   1095587251  511671895.45     Subiu    Equatorial Energia
# 17    600865451  143220991.46     Subiu  Siderúrgica Nacional
# 18    289347914   72295838.99     Subiu                 YDUQS
# 19   1086411192  388705223.96     Subiu              Ultrapar
# 20    376187582   37525872.38     Subiu                   MRV
# 21     62305891   41021792.09     Subiu                Arezzo
# 22   5146576868  822148336.41     Subiu        Banco Bradesco
# 23   5146576868  822148336.41     Subiu        Banco Bradesco
# 24    261036182   18214628.10     Subiu               Minerva
# 25    159430826    6340916.22     Subiu   Grupo Pão de Açúcar
# 26   1677525446  233045769.57     Subiu                   BRF
# 27    423091712  188965307.06     Subiu                  Vivo
# 28   1218352541  229771333.63     Subiu                  Rumo
# 29   1095462329   43657683.38     Subiu                 Cielo
# 30    302768240   18068446.61     Subiu                 Dexco
# 31    807896814  103972807.37     Subiu                   TIM
# 32    251003438   42238249.54     Subiu             Bradespar
# 33    393173139   15598886.65     Subiu               Locaweb
# 34    275005663   46201006.00     Subiu        PetroRecôncavo
# 35   5372783971  373853994.88     Subiu                Itaúsa
# 36   1420949112  546752087.99     Subiu       Banco do Brasil
# 37   1275798515  202352473.74     Subiu          RaiaDrogasil
# 38    660411219   39045606.94     Subiu    Metalúrgica Gerdau
# 39   1168097881  127229653.18     Subiu                 Cosan
# 40   1134986472  156573285.43     Subiu                   JBS
# 41   2867627068   28493619.27     Subiu        Magazine Luiza
# 42   1500728902   74019610.05     Subiu        Banco Bradesco
# 43   1500728902   74019610.05     Subiu        Banco Bradesco
# 44   1118525506   65779607.10     Subiu                Gerdau
# 45   1193047233   11571106.42     Subiu                Raízen
# 46   1679335290   32069789.50     Subiu                 Copel
# 47    421383330    4131341.16     Subiu           Grupo Vamos
#
#             Segmento  Idade       Cat_Idade
# 0         Siderurgia     63  Entre 50 e 100
# 1         Siderurgia      9     Menos de 50
# 2           Petróleo     72  Entre 50 e 100
# 3           Petróleo     72  Entre 50 e 100
# 4              Papel    101     Mais de 100
# 5            Energia    112     Mais de 100
# 6           Petróleo     14     Menos de 50
# 7           Petróleo     72  Entre 50 e 100
# 8           Petróleo     72  Entre 50 e 100
# 9          Mineração     83  Entre 50 e 100
# 10          Shopping     51  Entre 50 e 100
# 11            Bancos    100  Entre 50 e 100
# 12             Saúde     47     Menos de 50
# 13      Petroquímica     22     Menos de 50
# 14           Aviação     17     Menos de 50
# 15          Petróleo     15     Menos de 50
# 16           Energia     26     Menos de 50
# 17        Siderurgia     84  Entre 50 e 100
# 18          Educação     52  Entre 50 e 100
# 19      Combustíveis     87  Entre 50 e 100
# 20        Construção     45     Menos de 50
# 21              Moda     52  Entre 50 e 100
# 22            Bancos     82  Entre 50 e 100
# 23            Bancos     82  Entre 50 e 100
# 24         Alimentos    103     Mais de 100
# 25            Varejo     80  Entre 50 e 100
# 26         Alimentos     89  Entre 50 e 100
# 27   Telecomunicação     27     Menos de 50
# 28         Logística     27     Menos de 50
# 29             Meios     30     Menos de 50
# 30           Madeira     74  Entre 50 e 100
# 31  Telecomunicações     27     Menos de 50
# 32           Holding     22     Menos de 50
# 33        Tecnologia     26     Menos de 50
# 34          Petróleo     67  Entre 50 e 100
# 35           Holding     48     Menos de 50
# 36            Bancos    217     Mais de 100
# 37            Varejo    116     Mais de 100
# 38        Siderurgia    124     Mais de 100
# 39           Energia     89  Entre 50 e 100
# 40         Alimentos     72  Entre 50 e 100
# 41            Varejo     68  Entre 50 e 100
# 42            Bancos     82  Entre 50 e 100
# 43            Bancos     82  Entre 50 e 100
# 44        Siderurgia    124     Mais de 100
# 45           Energia     14     Menos de 50
# 46           Energia     70  Entre 50 e 100
# 47         Logística     13     Menos de 50

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
display(df_analise_segmento)
# Out:
#             Segmento    Variacao_rs
# 0          Alimentos   407833683.09
# 1            Aviação    65452205.55
# 2             Bancos  4636679965.25
# 3       Combustíveis   388705223.96
# 4         Construção    37525872.38
# 5           Educação    72295838.99
# 6            Energia   821116399.61
# 7            Holding   416092244.42
# 8          Logística   233902674.79
# 9            Madeira    18068446.61
# 10             Meios    43657683.38
# 11         Mineração  4762926995.25
# 12              Moda    41021792.09
# 13             Papel   722946282.71
# 14      Petroquímica    69054317.64
# 15          Petróleo 11336484517.00
# 16             Saúde   453917907.01
# 17          Shopping   117732680.08
# 18        Siderurgia   667451901.23
# 19        Tecnologia    15598886.65
# 20   Telecomunicação   188965307.06
# 21  Telecomunicações   103972807.37
# 22            Varejo   237187009.24

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    Variacao_rs
# 0    Desceu -6338819961.32
# 1   Manteve           0.00
# 2     Subiu 25858590641.35

# %%
media_subiu = df_principal[df_principal["Resultado"] == "Subiu"]["Variacao_rs"].mean()
media_desceu = df_principal[df_principal["Resultado"] == "Desceu"]["Variacao_rs"].mean()

print(f"média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# média de quem subiu	R$ 538,720,638.36
# média de quem desceu	R$ -181,109,141.75

# %%
display(df_principal[['Nome', 'Idade', 'Cat_Idade']])
# Out:
#                 Nome  Idade       Cat_Idade
# 0           Usiminas     63  Entre 50 e 100
# 1      CSN Mineração      9     Menos de 50
# 2          Petrobras     72  Entre 50 e 100
# 3          Petrobras     72  Entre 50 e 100
# 4             Suzano    101     Mais de 100
# ..               ...    ...             ...
# 80  Carrefour Brasil     49     Menos de 50
# 81       Casas Bahia     73  Entre 50 e 100
# 82          Localiza     52  Entre 50 e 100
# 83               CVC     52  Entre 50 e 100
# 84               GOL     25     Menos de 50
#
# [85 rows x 3 columns]

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Resultado')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a6f12d3c-6821-4d15-b318-44a6c9023947" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6f12d3c-6821-4d15-b318-44a6c9023947")) {                    Plotly.newPlot(                        "a6f12d3c-6821-4d15-b318-44a6c9023947",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-6338819961.31535,0.0,25858590641.34758],"textposition":"auto","x":["Desceu","Manteve","Subiu"],"xaxis":"x","y":[-6338819961.31535,0.0,25858590641.34758],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"sca ...
